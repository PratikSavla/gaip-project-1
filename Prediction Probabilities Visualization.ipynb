# %%
import pandas as pd
import matplotlib.pyplot as plt
import pydicom
from pydicom.data import get_testdata_files
import seaborn as sns

# %%
df = pd.read_csv("prediction_probabilities.csv")

# %%
df.head()
# Out:
#            name Category_New   ICH   IPH   IVH   SDH   EDH   SAH  \
# 0  CQ500-CT-427           B2  0.99  0.46  0.07  0.36  0.03  0.33
# 1  CQ500-CT-181           B2  0.99  0.63  0.00  0.68  0.22  0.22
# 2   CQ500-CT-99           B1  0.25  0.01  0.00  0.08  0.00  0.12
# 3   CQ500-CT-47           B1  0.60  0.30  0.03  0.03  0.00  0.09
# 4  CQ500-CT-195           B1  0.46  0.31  0.00  0.15  0.02  0.10
#
#    CalvarialFracture  MassEffect  MidlineShift
# 0           0.029752        0.62          0.20
# 1           0.975000        1.00          1.00
# 2           0.029752        0.22          0.02
# 3           0.029752        0.29          0.02
# 4           0.029752        0.00          0.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 491 entries, 0 to 490
# Data columns (total 11 columns):
# name                 491 non-null object
# Category_New         491 non-null object
# ICH                  491 non-null float64
# IPH                  491 non-null float64
# IVH                  491 non-null float64
# SDH                  491 non-null float64
# EDH                  491 non-null float64
# SAH                  491 non-null float64
# CalvarialFracture    491 non-null float64
# MassEffect           491 non-null float64
# MidlineShift         491 non-null float64
# dtypes: float64(9), object(2)
# memory usage: 42.3+ KB

# %%
df.describe()
# Out:
#               ICH         IPH         IVH         SDH         EDH         SAH  \
# count  491.000000  491.000000  491.000000  491.000000  491.000000  491.000000
# mean     0.591609    0.349002    0.068228    0.163218    0.048982    0.155153
# std      0.362843    0.324578    0.190341    0.237711    0.110412    0.232846
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.210000    0.080000    0.000000    0.020000    0.000000    0.010000
# 50%      0.670000    0.220000    0.000000    0.060000    0.010000    0.050000
# 75%      0.960000    0.620000    0.010000    0.180000    0.050000    0.180000
# max      1.000000    1.000000    0.970000    1.000000    0.910000    0.960000
#
#        CalvarialFracture  MassEffect  MidlineShift
# count         491.000000  491.000000    491.000000
# mean            0.194557    0.234542      0.155316
# std             0.260713    0.335056      0.301685
# min             0.000000    0.000000      0.000000
# 25%             0.029752    0.010000      0.000000
# 50%             0.040000    0.050000      0.000000
# 75%             0.290000    0.315000      0.110000
# max             0.975000    1.000000      1.000000

# %%
df.hist(bins=16,figsize=(16,16));

# %%
plt.subplots(figsize=(16, 12))
sns.heatmap(df.corr(),annot=True, cmap=sns.color_palette("Blues"));

# %%
#to visualize the dcm images

# %%
filename = (r"CT000000.dcm")
ds = pydicom.dcmread(filename)
plt.imshow(ds.pixel_array, cmap=plt.cm.bone);
